# %%
import pandas as pd

data = pd.read_csv("CustomerServiceDataSet.csv")

# %%
data.head()
# Out:
#   Branch   Call Purpose Time Block Incoming or Outgoing Queue Rep ID Sale  \
# 0  North      Complaint    9:00 AM             Incoming     B  Brent   NO
# 1  South  Sales Support   10:00 AM             Incoming     D   Kate   NO
# 2  South  Sales Support   10:00 AM             Incoming     C   Eric   NO
# 3  South  Sales Support   10:00 AM             Incoming     C  Susan   NO
# 4  South  Sales Support   10:00 AM             Incoming     C  Alice   NO
#
#    Lost Call  Abandoned  Busy Minutes  Not Ready Minutes  Incoming Wait Time  \
# 0          0          1             9                  2                 1.0
# 1          0          0             9                  1                 1.0
# 2          0          0             8                  2                 1.0
# 3          0          0            10                  2                 1.0
# 4          0          0            12                  1                 1.0
#
#    During Call Wait Time  Calls
# ...
